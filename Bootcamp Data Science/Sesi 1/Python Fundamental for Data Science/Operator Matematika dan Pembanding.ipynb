# %% [markdown]
# ![operator%20aritmatika.png](attachment:operator%20aritmatika.png)

# %% [markdown]
# ## [Praktek Operasi Matematika](https://academy.dqlab.id/main/livecode/45/112/534?pr=0)

# %%
a=10
b=5
selisih = a-b
jumlah = a+b
kali = a*b
bagi = a/b
print("Hasil penjumlahan a dan b adalah", jumlah)
print("Selisih a dan b adalah :",selisih)
print("Hasil perkalian a dan b adalah :",kali)
print("Hasil pembagian a dan b adalah:",bagi)
# Out:
# Hasil penjumlahan a dan b adalah 15
# Selisih a dan b adalah : 5
# Hasil perkalian a dan b adalah : 50
# Hasil pembagian a dan b adalah: 2.0

# %% [markdown]
# ## [Operasi modulus](https://academy.dqlab.id/main/livecode/45/112/536?pr=0)

# %%
c=10
d=3
modulus=c%d
print("Hasil modulus",modulus)
# Out:
# Hasil modulus 1

# %% [markdown]
# ## [Tugas Mid Praktek](https://academy.dqlab.id/main/livecode/45/112/538?pr=0)

# %%
angka=5

if(angka%2==0):
    print("angka termasuk bilangan genap")
else:
    print("angka termasuk bilangan ganjil")
# Out:
# angka termasuk bilangan ganjil
